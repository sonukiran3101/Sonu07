# %% [markdown]
# <a href="https://colab.research.google.com/github/sonukiran3101/Sonu07/blob/master/PDF_to_CSV.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install git+https://github.com/pdftables/python-pdftables-api.git
# Out:
# ...
#   Cloning https://github.com/pdftables/python-pdftables-api.git to /tmp/pip-req-build-c4n0rqxl
#   Running command git clone -q https://github.com/pdftables/python-pdftables-api.git /tmp/pip-req-build-c4n0rqxl
# ...
#   Created wheel for pdftables-api: filename=pdftables_api-1.1.0-cp37-none-any.whl size=5882 sha256=d7e244c3bfaa8d2f32dd6f4b8205268634189e1904715073c5af85dfe253837b
#   Stored in directory: /tmp/pip-ephem-wheel-cache-7s35005r/wheels/49/66/c0/e4f778e772a77892a98b3aaaba300cbb27a29a07e0c225cd80
# Successfully built pdftables-api
# ...

# %%
import pdftables_api

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
 # API KEY VERIFICATION
conversion = pdftables_api.Client('aio61n3i92db')

pdf_file_path = "/content/gdrive/My Drive/zignaa_analytics/Sample_Form.pdf"
output_file_path = "/content/gdrive/My Drive/zignaa_analytics/Sample_Form_csv.csv"
# PDf to CSV 
# (Hello.pdf, Hello)
conversion.csv(pdf_file_path, output_file_path)

# %%
import pandas as pd
df = pd.read_csv("/content/gdrive/My Drive/zignaa_analytics/Sample_Form_csv.csv")

# %%
df.head(30)
# Out:
#                                            Unnamed: 0  ...               Unnamed: 10
# 0          Name _P_e_r_s_o_n_ _N_m__a_e______________  ...           Emerging Talent
# 1                                                      ...  Key Function/Site Talent
# 2                                                      ...
# 3                              **All boxes associated  ...
# 4                                with a category/tier  ...
# 5                              must be checked for an  ...
# 6                             individual to be ADEPT.  ...
# 7                                                      ...
# 8   HIGH\nPERF-ORMANCE\nIs the TM ahigh performer?...  ...
# 9                                                      ...
# 10                                         ENGAGEMENT  ...
# 11                                    Is TM committed  ...
# 12                                                     ...
# 13                                    and will he/she  ...
# ...

# %%
df = df.fillna(' ') # Replacing all the NAN values with empty string

# %%
df.head(30)
# Out:
#                                            Unnamed: 0  ...               Unnamed: 10
# 0          Name _P_e_r_s_o_n_ _N_m__a_e______________  ...           Emerging Talent
# 1                                                      ...  Key Function/Site Talent
# 2                                                      ...
# 3                              **All boxes associated  ...
# 4                                with a category/tier  ...
# 5                              must be checked for an  ...
# 6                             individual to be ADEPT.  ...
# 7                                                      ...
# 8   HIGH\nPERF-ORMANCE\nIs the TM ahigh performer?...  ...
# 9                                                      ...
# 10                                         ENGAGEMENT  ...
# 11                                    Is TM committed  ...
# 12                                                     ...
# 13                                    and will he/she  ...
# ...
